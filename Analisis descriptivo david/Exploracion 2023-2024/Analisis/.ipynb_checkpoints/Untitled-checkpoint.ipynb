# %%
import pandas as pd 
import missingno as msno


print("EXPLORACIÓN PRELIMINAR")

archivo_excel = 'C:/Users/David/Documents/Universidad/Grado/Exploracion/datosFontibon/data.xlsx'

nombre_hoja="DATA"
columnas = ['DateTime','PM10', 'CO','OZONO','NO','NO2','NOX','SO2','Vel Viento','Dir Viento','Temperatura','Precipitacion','PM2.5','HR','Presion Baro']



fila_inicio = 1

df = pd.read_excel(archivo_excel,sheet_name=nombre_hoja, skiprows=fila_inicio)
df.columns=columnas

print("Tamaño de los datos \nColumnas: ", df.shape[1],"\nFilas: ",df.shape[0] )
print("Datos perdidos")

msno.matrix(df)
# Out:
# EXPLORACIÓN PRELIMINAR
# Tamaño de los datos
# Columnas:  15
# Filas:  8759
# Datos perdidos
# información de las columnas
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8759 entries, 0 to 8758
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DateTime       8759 non-null   object
#  1   PM10           8759 non-null   object
#  2   CO             8759 non-null   object
#  3   OZONO          8759 non-null   object
#  4   NO             8759 non-null   object
#  5   NO2            8759 non-null   object
#  6   NOX            8759 non-null   object
#  7   SO2            8759 non-null   object
#  8   Vel Viento     8759 non-null   object
#  9   Dir Viento     8759 non-null   object
#  10  Temperatura    8759 non-null   object
#  11  Precipitacion  8759 non-null   object
#  12  PM2.5          8759 non-null   object
#  13  HR             8759 non-null   object
#  14  Presion Baro   8759 non-null   object
# dtypes: object(15)
# memory usage: 1.0+ MB

# %%
import pandas as pd 
import missingno as msno


print("EXPLORACIÓN PRELIMINAR")

archivo_excel = 'C:/Users/David/Documents/Universidad/Grado/Exploracion/datosFontibon/data.xlsx'

nombre_hoja="DATA"
columnas = ['DateTime','PM10', 'CO','OZONO','NO','NO2','NOX','SO2','Vel Viento','Dir Viento','Temperatura','Precipitacion','PM2.5','HR','Presion Baro']



fila_inicio = 1

df = pd.read_excel(archivo_excel,sheet_name=nombre_hoja, skiprows=fila_inicio)
df.columns=columnas
print("información de las columnas")
df.info()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd
# ----> 2 import missingno as msno
#       5 print("EXPLORACIÓN PRELIMINAR")
#       7 archivo_excel = 'C:/Users/David/Documents/Universidad/Grado/Exploracion/datosFontibon/data.xlsx'
#
# ModuleNotFoundError: No module named 'missingno'
